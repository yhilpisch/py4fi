# %% [markdown]
# <img src="http://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>

# %% [markdown]
# # Python for Finance

# %% [markdown]
# **Analyze Big Financial Data**
#
# O'Reilly (2014)
#
# Yves Hilpisch

# %% [markdown]
# <img style="border:1px solid grey;" src="http://hilpisch.com/python_for_finance.png" alt="Python for Finance" width="30%" align="left" border="0">

# %% [markdown]
# **Buy the book ** |
# <a href='http://shop.oreilly.com/product/0636920032441.do' target='_blank'>O'Reilly</a> |
# <a href='http://www.amazon.com/Yves-Hilpisch/e/B00JCYHHJM' target='_blank'>Amazon</a>
#
# **All book codes & IPYNBs** |
# <a href="http://oreilly.quant-platform.com">http://oreilly.quant-platform.com</a>
#
# **The Python Quants GmbH** | <a href='http://pythonquants.com' target='_blank'>www.pythonquants.com</a>
#
# **Contact us** | <a href='mailto:analytics@pythonquants.com'>analytics@pythonquants.com</a>

# %% [markdown]
# # Web Integration

# %% [markdown]
# ## Web Basics

# %% [markdown]
# ### ftplib

# %%
import ftplib
import numpy as np

# %%
ftp = ftplib.FTP('quant-platform.com')

# %%
ftp.login(user='python', passwd='python')
# Out:
# '230 Login successful.'

# %%
np.save('./data/array', np.random.standard_normal((100, 100)))

# %%
f = open('./data/array.npy', 'r')

# %%
ftp.storbinary('STOR array.npy', f)
# Out:
# '226 Transfer complete.'

# %%
ftp.retrlines('LIST')
# Out:
# -rw-------    1 1001     1001        80080 Dec 15 05:17 array.npy
# '226 Directory send OK.'

# %%
f = open('./data/array_ftp.npy', 'wb').write

# %%
ftp.retrbinary('RETR array.npy', f)
# Out:
# '226 Transfer complete.'

# %%
ftp.delete('array.npy')
# Out:
# '250 Delete operation successful.'

# %%
ftp.retrlines('LIST')
# Out:
# '226 Directory send OK.'

# %%
ftp.close()

# %%
# !ls -n ./data
# Out:
# total 164
# -rw-r--r-- 1 1141 8 80080 Dec 15 11:20 array.npy
# -rw-r--r-- 1 1141 8 77824 Dec 15 11:21 array_ftp.npy

# %%
# !rm -f ./data/arr*
  # clean-up directory

# %%
ftps = ftplib.FTP_TLS('quant-platform.com')

# %%
ftps.login(user='python', passwd='python')
# Out:
# '230 Login successful.'

# %%
ftps.prot_p()
# Out:
# '200 PROT now Private.'

# %%
ftps.retrlines('LIST')
# Out:
# '226 Directory send OK.'

# %%
ftps.close()

# %% [markdown]
# ### httplib

# %%
import httplib

# %%
http = httplib.HTTPConnection('hilpisch.com')

# %%
http.request('GET', '/index.htm')

# %%
resp = http.getresponse()

# %%
resp.status, resp.reason
# Out:
# (200, 'OK')

# %%
content = resp.read()
content[:100]
  # first 100 characters of the file
# Out:
# '<!doctype html>\n<html lang="en">\n\n\t<head>\n\t\t<meta charset="utf-8">\n\n\t\t<title>Dr. Yves J. Hilpisch \xe2\x80'

# %%
index = content.find(' E ')
index
# Out:
# 2058

# %%
content[index:index + 29]
# Out:
# ' E contact [at] dyjh [dot] de'

# %%
http.close()

# %% [markdown]
# ### urllib

# %%
import urllib

# %%
url = 'http://ichart.finance.yahoo.com/table.csv?g=d&ignore=.csv'
url += '&s=YHOO&a=01&b=1&c=2014&d=02&e=6&f=2014'

# %%
connect = urllib.urlopen(url)

# %%
data = connect.read()

# %%
print data
# Out:
# Date,Open,High,Low,Close,Volume,Adj Close
# 2014-03-06,39.60,39.98,39.50,39.66,10626700,39.66
# 2014-03-05,39.83,40.15,39.19,39.50,12536800,39.50
# 2014-03-04,38.76,39.79,38.68,39.63,16139400,39.63
# 2014-03-03,37.65,38.66,37.43,38.25,14714700,38.25
# 2014-02-28,38.55,39.38,38.22,38.67,16957100,38.67
# 2014-02-27,37.80,38.48,37.74,38.47,15489400,38.47
# 2014-02-26,37.35,38.10,37.34,37.62,15778900,37.62
# 2014-02-25,37.48,37.58,37.02,37.26,9756900,37.26
# 2014-02-24,37.23,37.71,36.82,37.42,15738900,37.42
# 2014-02-21,37.90,37.96,37.22,37.29,12351900,37.29
# 2014-02-20,37.83,38.04,37.30,37.79,11155900,37.79
# 2014-02-19,38.06,38.33,37.68,37.81,15851900,37.81
# 2014-02-18,38.31,38.59,38.09,38.31,12096400,38.31
# 2014-02-14,38.43,38.45,38.11,38.23,9975800,38.23
# 2014-02-13,37.92,38.69,37.79,38.52,12088100,38.52
# 2014-02-12,38.60,38.91,38.03,38.11,14088500,38.11
# 2014-02-11,38.15,38.86,38.09,38.50,18348000,38.50
# 2014-02-10,38.00,38.13,37.25,37.76,17642900,37.76
# 2014-02-07,36.65,37.27,36.24,37.23,16178500,37.23
# 2014-02-06,35.65,36.75,35.61,36.24,14250000,36.24
# 2014-02-05,35.60,35.94,34.99,35.49,14022900,35.49
# 2014-02-04,35.11,35.86,34.86,35.66,21082500,35.66
# 2014-02-03,35.94,36.01,34.66,34.90,22195200,34.90

# %%
url = 'http://ichart.finance.yahoo.com/table.csv?g=d&ignore=.csv'
url += '&%s'  # for replacement with parameters
url += '&d=06&e=30&f=2014'

# %%
params = urllib.urlencode({'s': 'MSFT', 'a': '05', 'b': 1, 'c': 2014})

# %%
params
# Out:
# 'a=05&s=MSFT&b=1&c=2014'

# %%
url % params
# Out:
# 'http://ichart.finance.yahoo.com/table.csv?g=d&ignore=.csv&a=05&s=MSFT&b=1&c=2014&d=06&e=30&f=2014'

# %%
connect = urllib.urlopen(url % params)

# %%
data = connect.read()

# %%
print data
# Out:
# Date,Open,High,Low,Close,Volume,Adj Close
# 2014-07-30,44.07,44.10,43.29,43.58,31921400,43.04
# 2014-07-29,43.91,44.09,43.64,43.89,27763100,43.34
# 2014-07-28,44.36,44.51,43.93,43.97,29684200,43.42
# 2014-07-25,44.30,44.66,44.30,44.50,26737700,43.95
# 2014-07-24,44.93,45.00,44.32,44.40,30725300,43.85
# 2014-07-23,45.45,45.45,44.62,44.87,52362900,44.31
# 2014-07-22,45.00,45.15,44.59,44.83,43095800,44.27
# 2014-07-21,44.56,45.16,44.22,44.84,37604400,44.28
# 2014-07-18,44.65,44.84,44.25,44.69,43407500,44.13
# 2014-07-17,45.45,45.71,44.25,44.53,82180300,43.98
# 2014-07-16,42.51,44.31,42.48,44.08,63318000,43.53
# 2014-07-15,42.33,42.47,42.03,42.45,28748700,41.92
# 2014-07-14,42.22,42.45,42.04,42.14,21881100,41.62
# 2014-07-11,41.70,42.09,41.48,42.09,24083000,41.57
# 2014-07-10,41.37,42.00,41.05,41.69,21854700,41.17
# 2014-07-09,41.98,41.99,41.53,41.67,18445900,41.15
# 2014-07-08,41.87,42.00,41.61,41.78,31218200,41.26
# 2014-07-07,41.75,42.12,41.71,41.99,21952400,41.47
# 2014-07-03,41.91,41.99,41.56,41.80,15969300,41.28
# 2014-07-02,41.73,41.90,41.53,41.90,20208100,41.38
# 2014-07-01,41.86,42.15,41.69,41.87,26917000,41.35
# 2014-06-30,42.17,42.21,41.70,41.70,30805500,41.18
# 2014-06-27,41.61,42.29,41.51,42.25,74640000,41.72
# 2014-06-26,41.93,41.94,41.43,41.72,23604400,41.20
# 2014-06-25,41.70,42.05,41.46,42.03,20049100,41.51
# 2014-06-24,41.83,41.94,41.56,41.75,26509100,41.23
# 2014-06-23,41.73,42.00,41.69,41.99,18743900,41.47
# 2014-06-20,41.45,41.83,41.38,41.68,47764900,41.16
# 2014-06-19,41.57,41.77,41.33,41.51,19828200,40.99
# 2014-06-18,41.61,41.74,41.18,41.65,27097000,41.13
# 2014-06-17,41.29,41.91,40.34,41.68,22518600,41.16
# 2014-06-16,41.04,41.61,41.04,41.50,24205300,40.98
# 2014-06-13,41.10,41.57,40.86,41.23,26310000,40.72
# 2014-06-12,40.81,40.88,40.29,40.58,29818900,40.08
# 2014-06-11,40.93,41.07,40.77,40.86,18040000,40.35
# 2014-06-10,41.03,41.16,40.86,41.11,15117700,40.60
# 2014-06-09,41.39,41.48,41.02,41.27,15019200,40.76
# 2014-06-06,41.48,41.66,41.24,41.48,24060500,40.96
# 2014-06-05,40.59,41.25,40.40,41.21,31865200,40.70
# 2014-06-04,40.21,40.37,39.86,40.32,23209000,39.82
# 2014-06-03,40.60,40.68,40.25,40.29,18068900,39.79
# 2014-06-02,40.95,41.09,40.68,40.79,18504300,40.28

# %%
urllib.urlretrieve(url % params, './data/msft.csv')
# Out:
# ('./data/msft.csv', <httplib.HTTPMessage instance at 0x7f80012a3440>)

# %%
csv = open('./data/msft.csv', 'r')
csv.readlines()[:5]
# Out:
# ['Date,Open,High,Low,Close,Volume,Adj Close\n',
#  '2014-07-30,44.07,44.10,43.29,43.58,31921400,43.04\n',
#  '2014-07-29,43.91,44.09,43.64,43.89,27763100,43.34\n',
#  '2014-07-28,44.36,44.51,43.93,43.97,29684200,43.42\n',
#  '2014-07-25,44.30,44.66,44.30,44.50,26737700,43.95\n']

# %%
# !rm -f ./data/*

# %% [markdown]
# ## Web Plotting

# %% [markdown]
# ### Static Plots

# %%
import numpy as np
import pandas as pd
# %matplotlib inline

# %%
url = 'http://ichart.yahoo.com/table.csv?s=MSFT&a=0&b=1&c=2009'
data = pd.read_csv(url, parse_dates=['Date'])

# %%
data.plot(x='Date', y='Close')
# tag: microsoft
# title: Historical stock prices for Microsoft since January 2009 (+matplotlib+)

# %%
import bokeh.plotting as bp

# %%
bp.output_file("./images/msft_1.html", title="Bokeh Example (Static)")
# use: bp.output_notebook("default")
# for output within an IPython Notebook
# Out:
# Session output file './images/msft_1.html' already exists, will be overwritten.

# %%
bp.line(
    data['Date'],                                   
        # x coordinates
    data['Close'],
        # y coordinates
    color='#0066cc',                                    
        # set a color for the line
    legend='MSFT',                                      
        # attach a legend label
    title='Historical Stock Quotes',
        # plot title
    x_axis_type='datetime',                           
        # datetime information on x axis
    tools = ''
)
bp.show()

# %% [markdown]
# ### Interactive Plots

# %%
bp.output_file("./images/msft_2.html",
               title="Bokeh Example (Interactive)")
bp.line(
    data['Date'],                                   
    data['Close'],
    color='#0066cc',                                    
    legend='MSFT',                                  
    title='Historical Stock Quotes',
    x_axis_type = "datetime",                           
    tools = 'pan, wheel_zoom, box_zoom, reset, previewsave'
        # adding a list of interactive tools
)
bp.show()
# Out:
# Session output file './images/msft_2.html' already exists, will be overwritten.

# %% [markdown]
# ### Real-Time Plots

# %% [markdown]
# #### Real-Time FX Data

# %%
import time
import pandas as pd
import datetime as dt
import requests

# %%
url = 'http://api-sandbox.oanda.com/v1/prices?instruments=%s'
  # real-time FX (dummy!) data from JSON API

# %%
instrument = 'EUR_USD'
api = requests.get(url % instrument)

# %%
data = api.json()
data
# Out:
# {u'prices': [{u'ask': 1.24079,
#    u'bid': 1.24064,
#    u'instrument': u'EUR_USD',
#    u'time': u'2014-12-15T10:17:15.394294Z'}]}

# %%
data = data['prices'][0]
data
# Out:
# {u'ask': 1.24079,
#  u'bid': 1.24064,
#  u'instrument': u'EUR_USD',
#  u'time': u'2014-12-15T10:17:15.394294Z'}

# %%
ticks = pd.DataFrame({'bid': data['bid'],
                      'ask': data['ask'],
                      'instrument': data['instrument'],
                      'time': pd.Timestamp(data['time'])},
                      index=[pd.Timestamp(data['time']),])
  # initialization of ticks DataFrame

# %%
ticks[['ask', 'bid', 'instrument']]
# Out:
#                                 ask      bid instrument
# 2014-12-15 10:17:15.394294  1.24079  1.24064    EUR_USD

# %% [markdown]
# #### Real-Time Stock Price Quotes

# %%
url1 = 'http://hopey.netfonds.no/posdump.php?'
url2 = 'date=%s%s%s&paper=%s.O&csv_format=csv'
url = url1 + url2

# %%
today = dt.datetime.now()
y = '%d' % today.year
  # current year
m = '%02d' % today.month
  # current month, add leading zero if needed
d = '%02d' % (today.day)
  # current day, add leading zero if needed
sym = 'AAPL'
  # Apple Inc. stocks

# %%
y, m, d, sym
# Out:
# ('2014', '12', '15', 'AAPL')

# %%
urlreq = url % (y, m, d, sym)
urlreq
# Out:
# 'http://hopey.netfonds.no/posdump.php?date=20141215&paper=AAPL.O&csv_format=csv'

# %%
data = pd.read_csv(urlreq, parse_dates=['time'])
  # initialize DataFrame object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 114 entries, 0 to 113
# Data columns (total 7 columns):
# time                 114 non-null datetime64[ns]
# bid                  114 non-null float64
# bid_depth            114 non-null int64
# bid_depth_total      114 non-null int64
# offer                114 non-null float64
# offer_depth          114 non-null int64
# offer_depth_total    114 non-null int64
# dtypes: datetime64[ns](1), float64(2), int64(4)
# memory usage: 7.1 KB

# %% [markdown]
# ## Rapid Web Applications

# %% [markdown]
# ### Traders' Chat Room

# %% [markdown]
# ### Data Modeling

# %% [markdown]
# ### The Python Code

# %% [markdown]
# #### Imports and Database Preliminaries

# %% [markdown]
# #### Core Functionality

# %% [markdown]
# ### Templating

# %%
'%d, %d, %d' % (1, 2, 3)
# Out:
# '1, 2, 3'

# %%
'{}, {}, {}'.format(1, 2, 3)
# Out:
# '1, 2, 3'

# %%
'{}, {}, {}'.format(*'123')
# Out:
# '1, 2, 3'

# %%
templ = '''<!doctype html>
  Just print out <b>numbers</b> provided to the template.
  <br><br>
  {% for number in numbers %}
    {{ number }}
  {% endfor %}
'''

# %%
from jinja2 import Template

# %%
t = Template(templ)

# %%
html = t.render(numbers=range(5))

# %%
html
# Out:
# u'<!doctype html>\n  Just print out <b>numbers</b> provided to the template.\n  <br><br>\n  \n    0\n  \n    1\n  \n    2\n  \n    3\n  \n    4\n  '

# %%
from IPython.display import HTML
HTML(html)
# Out:
# <!doctype html>
#   Just print out <b>numbers</b> provided to the template.
#   <br><br>
#
#     0
#
#     1
#
#     2
#
#     3
#
#     4

# %% [markdown]
# ### Styling

# %%
import os
for path, dirs, files in os.walk('../python/tradechat'):
  print path
  for f in files:
    print f
# Out:
# ../python/tradechat
# tradechat.db
# tables.sql
# tradechat.py
# ../python/tradechat/templates
# show_entries.html
# layout.html
# register.html
# login.html
# ../python/tradechat/static
# style.css

# %% [markdown]
# ## Web Services

# %% [markdown]
# ### The Financial Model

# %% [markdown]
# ### The Implementation

# %%
import sys
sys.path.append("../python/volservice")
  # adjust if necessary to your path

# %%
from werkzeug.wrappers import Request, Response

# %%
from vol_pricing_service import get_option_value

# %%
def application(environ, start_response):
    request = Request(environ)
      # wrap environ in new object
    text = get_option_value(request.args)
      # provide all paramters of the call to function
      # get back either error message or option value
    response = Response(text, mimetype='text/html')
      # generate response object based on the returned text
    return response(environ, start_response)

# %%
import numpy as np
import urllib
url = 'http://localhost:4000/'

# %% [markdown]
# ## Conclusions

# %% [markdown]
# ## Further Reading

# %% [markdown]
# <img src="http://hilpisch.com/tpq_logo.png" alt="The Python Quants" width="35%" align="right" border="0"><br>
#
# <a href="http://www.pythonquants.com" target="_blank">www.pythonquants.com</a> | <a href="http://twitter.com/dyjh" target="_blank">@dyjh</a>
#
# <a href="mailto:analytics@pythonquants.com">analytics@pythonquants.com</a>
#
# **Python Quant Platform** |
# <a href="http://oreilly.quant-platform.com">http://oreilly.quant-platform.com</a>
#
# **Derivatives Analytics with Python** |
# <a href="http://www.derivatives-analytics-with-python.com" target="_blank">Derivatives Analytics @ Wiley Finance</a>
#
# **Python for Finance** |
# <a href="http://shop.oreilly.com/product/0636920032441.do" target="_blank">Python for Finance @ O'Reilly</a>
